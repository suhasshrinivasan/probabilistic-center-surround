# %%
from probcs.datajoint.exc_tables import CustomBinaryConfig, CustomBinaryResult, schema
# Out:
# [2024-02-06 08:02:18,682][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2024-02-06 08:02:18,783][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
CustomBinaryResult()
# Out:
# *config_id     all_idata  all_stimul disrupting
# +------------+ +--------+ +--------+ +--------+
# 27a0b0901e0332 =BLOB=     =BLOB=     =BLOB=
# 5a5535b810b9e1 =BLOB=     =BLOB=     =BLOB=
# 73da831e183a03 =BLOB=     =BLOB=     =BLOB=
# 58dfed1f07841d =BLOB=     =BLOB=     =BLOB=
# 20fde9e170538c =BLOB=     =BLOB=     =BLOB=
# c74b70df7456a9 =BLOB=     =BLOB=     =BLOB=
# 33eca61e553488 =BLOB=     =BLOB=     =BLOB=
# 6d4ba943545454 =BLOB=     =BLOB=     =BLOB=
# 5d2504f0beed82 =BLOB=     =BLOB=     =BLOB=
# f52bf1536d9fa9 =BLOB=     =BLOB=     =BLOB=
# 9aa822b2305e68 =BLOB=     =BLOB=     =BLOB=
# 170aca6956072b =BLOB=     =BLOB=     =BLOB=
#    ...
#  (Total: 20)

# %%
ratio = lambda alpha: (0.05 + 0.75 * alpha) / (0.05 + 0.375 * alpha)

# %%
ratio(0.5)
# Out:
# 1.7894736842105263

# %%
ratio(0.1)
# Out:
# 1.4285714285714284

# %%
ratio(0.2)
# Out:
# 1.6

# %%
ratio(0.9)
# Out:
# 1.870967741935484

# %%
CustomBinaryConfig()

# %%
CustomBinaryResult()
# Out:
# *config_id    all_idata  all_stimul disrupting
# +-----------+ +--------+ +--------+ +--------+
#
#  (Total: 0)

# %%
CustomBinaryConfig()
# Out:
# *config_id     seed     g_dim     g_prob     i_sigma     patterns_offse image_type     n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +--------+ +---------+ +------------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 170aca6956072b 42       5         0.4        80.0        0.0            exc            600        600         4            4
# 20fde9e170538c 42       5         0.5        80.0        0.0            exc            600        600         4            4
# 27a0b0901e0332 42       5         0.6        60.0        0.0            exc            600        600         4            4
# 33eca61e553488 42       5         0.5        120.0       0.0            exc            600        600         4            4
# 4805bf5c38e47b 42       5         0.1        120.0       0.0            exc            600        600         4            4
# ...

# %%
# CustomBinaryResult.drop()
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 CustomBinaryResult.drop()
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/table.py:651, in Table.drop(self)
#     647 self.connection.dependencies.load()
#     648 do_drop = True
#     649 tables = [
#     650     table
# --> 651     for table in self.connection.dependencies.descendants(self.full_table_name)
#     652     if not table.isdigit()
#     653 ]
#     655 # avoid dropping part tables without their masters: See issue #374
#     656 for part in tables:
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/dependencies.py:170, in Dependencies.descendants(self, full_table_name)
#     165 """
#     166 :param full_table_name:  In form `schema`.`table_name`
#     167 :return: all dependent tables sorted in topological order.  Self is included.
#     168 """
# ...

# %%
from probcs.datajoint.exc_tables import BernoulliConfig, BernoulliResult, schema
# Out:
# [2024-02-01 12:29:56,742][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2024-02-01 12:29:56,839][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
BernoulliConfig()
# Out:
# *config_id    seed     g_dim     g_prob     i_sigma     patterns_offse offset_x_1     offset_x_2     scale_x     exponent_x     n_tune     n_draws     n_chains     n_cores
# +-----------+ +------+ +-------+ +--------+ +---------+ +------------+ +------------+ +------------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
#
#  (Total: 0)

# %%
BernoulliResult()
# Out:
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File /usr/local/lib/python3.8/dist-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %%
BernoulliResult.drop()
# Out:
# [2024-02-01 12:06:47,189][INFO]: `sshrinivasan_probcs`.`__bernoulli_result` (1 tuples)

# %%
BernoulliConfig().drop()
# Out:
# [2024-02-01 12:05:43,944][INFO]: `sshrinivasan_probcs`.`bernoulli_config` (16 tuples)
# [2024-02-01 12:05:43,995][INFO]: `sshrinivasan_probcs`.`__bernoulli_result` (1 tuples)

# %%
BernoulliResult()
# Out:
# *config_id     all_idata  all_stimul average_exc    average_inh_1  average_inh_2  disrupting
# +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +--------+
# 23c8ed4366f656 =BLOB=     =BLOB=     0.0            0.0            0.0            =BLOB=
#  (Total: 1)

# %%
BernoulliConfig()
# Out:
# *config_id     seed     g_dim     g_prob       i_sigma     patterns_offse offset_x_1     offset_x_2     scale_x     exponent_x     n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +----------+ +---------+ +------------+ +------------+ +------------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 0580b122cd6780 42       5         0.5          30.0        0.0            0.0            1.0            0.1         3.0            1000       1000        4            4
# 177a3599245c1a 42       5         0.2          30.0        0.0            0.0            1.0            0.1         3.0            1000       1000        4            4
# 1b3eef4d926bc7 42       5         0.2          10.0        0.0            0.0            1.0            0.1         3.0            1000       1000        4            4
# ...

# %%
BernoulliResult.drop()
# Out:
# [2024-02-01 12:03:28,509][INFO]: `sshrinivasan_probcs`.`__bernoulli_result` (1 tuples)

# %%
BernoulliConfig.drop()
# Out:
# [2024-02-01 12:02:13,420][INFO]: `sshrinivasan_probcs`.`bernoulli_config` (16 tuples)
# [2024-02-01 12:02:13,470][INFO]: `sshrinivasan_probcs`.`__bernoulli_result` (1 tuples)

# %%
BernoulliConfig.drop()
# Out:
# [2024-02-01 12:01:45,674][INFO]: `sshrinivasan_probcs`.`bernoulli_config` (16 tuples)
# [2024-02-01 12:01:45,726][INFO]: `sshrinivasan_probcs`.`__bernoulli_result` (1 tuples)

# %%
BernoulliResult()
# Out:
# *config_id     all_idata  all_stimul average_exc    average_inh_1  average_inh_2  disrupting
# +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +--------+
# 23c8ed4366f656 =BLOB=     =BLOB=     0.0            0.0            0.0            =BLOB=
#  (Total: 1)

# %%
from probcs.datajoint.exc_tables import (
    ExcExponentCenterCropConfig,
    ExcExponentCenterCropResult,
    schema,
)
# Out:
# [2024-02-01 10:19:06,697][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2024-02-01 10:19:06,795][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
ExcExponentCenterCropResult()
# Out:
# *config_id     all_idata  all_stimul average_exc    average_inh_1  average_inh_2  disrupting
# +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +--------+
# 0244f1a5c85c52 =BLOB=     =BLOB=     11.2546        7.98234        8.58323        =BLOB=
# 03273056f291fe =BLOB=     =BLOB=     0.0529325      -3.51685       -3.18521       =BLOB=
# 06e0f238ea0279 =BLOB=     =BLOB=     6.43786        -2.38509       -2.08972       =BLOB=
# 088565201881af =BLOB=     =BLOB=     12.687         -0.278077      1.41123        =BLOB=
# 12283f1eaf1c74 =BLOB=     =BLOB=     12.0366        8.02003        8.74785        =BLOB=
# 14144d7059cb54 =BLOB=     =BLOB=     17.6823        9.00575        10.9365        =BLOB=
# 1c1cb403e0b5b3 =BLOB=     =BLOB=     24.6059        9.17149        8.73559        =BLOB=
# 2031a8e1b19a5e =BLOB=     =BLOB=     2.97089        0.656263       1.76006        =BLOB=
# ...

# %%
from probcs.datajoint.exc_tables import ExcExponentResult, ExcExponentConfig, schema
# Out:
# [2023-12-07 16:42:45,344][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2023-12-07 16:42:45,450][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
ExcExponentConfig()
# Out:
# *config_id     seed     g_dim     g_prob        x_sigma     i_sigma     patterns_offse g_x_exponent   n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +-----------+ +---------+ +---------+ +------------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 0244f1a5c85c52 42       5         0.0666667     0.5         20.0        0.0            4              500        500         4            4
# 03273056f291fe 42       5         0.0666667     0.3         10.0        0.0            2              500        500         4            4
# 03ce71dabff130 42       5         0.0769231     0.5         20.0        0.0            2              500        500         4            4
# 048a46147e9194 42       5         0.0666667     0.7         10.0        0.0            1              500        500         4            4
# ...

# %%
ExcExponentResult()
# Out:
# *config_id     all_idata  all_stimul average_exc    average_inh_1  average_inh_2  disrupting
# +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +--------+
# 07a4d38112e7d3 =BLOB=     =BLOB=     0.518358       0.0773055      -0.373781      =BLOB=
# 07d815b4bb83c6 =BLOB=     =BLOB=     4.05205        -1.10583       -0.438278      =BLOB=
# 085e8a70f15de9 =BLOB=     =BLOB=     5.7603         -1.20418       -0.149623      =BLOB=
# 0fa09eb7b188a7 =BLOB=     =BLOB=     0.0628108      -0.0819003     0.0426926      =BLOB=
# 15be8aa70d3c69 =BLOB=     =BLOB=     2.70477        -0.155443      -0.114039      =BLOB=
# 18c7f0a1d34556 =BLOB=     =BLOB=     2.44929        -0.41174       -0.062577      =BLOB=
# 21bd690946eca1 =BLOB=     =BLOB=     3.34643        -0.783247      -0.0738959     =BLOB=
# 2b87c27f34365d =BLOB=     =BLOB=     1.17795        -0.235523      0.0349181      =BLOB=
# ...

# %%
results = ExcExponentConfig() * ExcExponentResult()
key_results = results.fetch(
    "config_id",
    "average_exc",
    "average_inh_1",
    "average_inh_2",
    order_by="average_inh_1",
    as_dict=True,
)

# %%
key_results
# Out:
# [{'config_id': '32645fb5a995f73c4aba131b1c598425',
#   'average_exc': 15.0821,
#   'average_inh_1': -3.43137,
#   'average_inh_2': 0.326527},
#  {'config_id': 'aca8c915babf3d407cb5f0b31b85f38f',
#   'average_exc': 13.7625,
#   'average_inh_1': -3.39125,
#   'average_inh_2': -0.776241},
#  {'config_id': 'd332b87ce0b6fa38e99f05020e32a801',
#   'average_exc': 9.91572,
#   'average_inh_1': -2.44244,
#   'average_inh_2': -0.566668},
#  {'config_id': 'fe648bfc9e2bca40827e6aff8fdcde2b',
#   'average_exc': 9.66324,
#   'average_inh_1': -2.27927,
#   'average_inh_2': -0.548248},
#  {'config_id': '8bdc18a4a9d5a7fb6f6cb322f4c62df7',
#   'average_exc': 5.82765,
#   'average_inh_1': -2.11922,
#   'average_inh_2': -0.465477},
#  {'config_id': 'dc08df028fd72d13ad9c5451b9a8ece8',
#   'average_exc': 7.97149,
#   'average_inh_1': -1.87152,
#   'average_inh_2': -0.330507},
#  {'config_id': '38215d37feb1bdc9a561339ca1d018bc',
#   'average_exc': 7.53699,
#   'average_inh_1': -1.50182,
# ...

# %%
from probcs.datajoint.grating_tables import (
    GratingConfig,
    GratingResult2,
    schema,
    GratingConfig10Plus,
    GratingResult10Plus,
)
from probcs.datajoint.exc_tables import (
    ExcConfig,
    ExcResult2,
    ExcConfig10Plus,
    ExcResult10Plus,
)
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# [2023-12-03 10:42:00,483][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2023-12-03 10:42:00,603][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
ExcResult10Plus()
# Out:
# *config_id     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 323f15da6ec49b =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 6eac1cd76fa381 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#  (Total: 2)

# %%
GratingResult10Plus()
# Out:
# *config_id     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 25e773ade7b5ab =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# f6d8143e6cb4f7 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 7b712589fa5c7d =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# c83c2cd5c1b80c =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 2e8d0c98d3b03f =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# d1a89718133700 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#  (Total: 6)

# %%
GratingConfig10Plus()
# Out:
# *config_id     seed     g_dim     g_prob     x_sigma     i_sigma     patterns_offse n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +--------+ +---------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 0393c5155877a9 42       10        0.1        0.1         1.5         0.6            500        500         4            4
# 03c8a089253ce8 42       10        0.05       0.1         2.0         0.0            500        500         4            4
# 25e773ade7b5ab 42       10        0.05       0.1         1.0         0.2            500        500         4            4
# 2ae1902901cf85 42       20        0.1        0.1         1.0         0.0            500        500         4            4
# 2e8d0c98d3b03f 42       10        0.05       0.1         1.5         0.4            500        500         4            4
# ...

# %%
GratingResult10Plus()
# Out:
# *config_id     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 25e773ade7b5ab =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# f6d8143e6cb4f7 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 7b712589fa5c7d =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# c83c2cd5c1b80c =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 2e8d0c98d3b03f =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# d1a89718133700 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#  (Total: 6)

# %%
dj_error_stack(schema.jobs, "007f7f73b0db67abd7eeb042a31736be")

# %%
schema.jobs
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host      pid       connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +-------+ +-------+ +------------+ +------------+
# __exc_result10 007f7f73b0db67 reserved     =BLOB=                    =BLOB=     sshrinivasan@k g3081     12880     70946          2023-11-30 13:
# __exc_result10 04a4c44ad95db2 reserved     =BLOB=                    =BLOB=     sshrinivasan@k g3045     79010     70954          2023-11-30 13:
# __exc_result10 1b0c96fe3d92e2 reserved     =BLOB=                    =BLOB=     sshrinivasan@k g3014     81018     70899          2023-11-30 11:
# __exc_result10 1faaab787d8a43 reserved     =BLOB=                    =BLOB=     sshrinivasan@k n3023     67909     70945          2023-11-30 13:
# ...

# %%
(schema.jobs & "key_hash = '007f7f73b0db67abd7eeb042a31736be'").fetch1()
# Out:
# {'table_name': '__exc_result10_plus',
#  'key_hash': '007f7f73b0db67abd7eeb042a31736be',
#  'status': 'reserved',
#  'key': {'config_id': 'f87058412ef06f82cbca689fcefc4e0c'},
#  'error_message': '',
#  'error_stack': None,
#  'user': 'sshrinivasan@klone-dip1-a.hyak.uw.edu',
#  'host': 'g3081',
#  'pid': 12880,
#  'connection_id': 70946,
#  'timestamp': datetime.datetime(2023, 11, 30, 13, 29, 18)}

# %%
GratingConfig()
# Out:
# *config_id     seed     g_dim     g_prob     x_sigma     i_sigma     patterns_offse n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +--------+ +---------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 0a666da60d1c33 42       5         0.2        0.1         2.0         0.2            500        500         4            4
# 163c471502e5f9 42       5         0.4        0.1         1.0         0.2            500        500         4            4
# 1ec6c4519fb1a9 42       5         0.2        0.1         1.5         0.2            500        500         4            4
# 25e38d0253358e 42       5         0.4        0.1         2.0         0.4            500        500         4            4
# 52b3839cd1025e 42       5         0.4        0.1         1.0         0.6            500        500         4            4
# ...

# %%
GratingResult2()
# Out:
# *config_id     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# ab8c342a89044d =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# f290be75283512 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# bac5889bd5e1e6 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1ec6c4519fb1a9 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 0a666da60d1c33 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 25e38d0253358e =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 691280ee04ec05 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# ...

# %%
ExcConfig()
# Out:
# *config_id     seed     g_dim     g_prob     x_sigma     i_sigma     patterns_offse n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +--------+ +---------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 26dc2ce7668fb9 42       4         0.4        0.1         5.0         0.0            500        500         4            4
# 375790809d6424 42       4         0.5        0.1         20.0        0.0            500        500         1            1
# 4b5bfbc0885f40 42       10        0.1        0.1         5.0         0.0            500        500         4            4
# 60aeef325e38e4 42       4         0.2        0.1         20.0        0.0            500        500         4            4
# 60eac5de7cd06b 42       10        0.1        0.1         10.0        0.0            500        500         4            4
# ...

# %%
ExcResult2()
# Out:
# *config_id     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 26dc2ce7668fb9 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 4b5bfbc0885f40 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# e7b858219c6b3d =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# eb9bf373eabf57 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 60eac5de7cd06b =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 90e806dca37a81 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 60aeef325e38e4 =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# ...

# %%
ExcResult10Plus()
# Out:
# *config_id     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 323f15da6ec49b =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#  (Total: 1)

# %%
ExcConfig()
# Out:
# *config_id     seed     g_dim     g_prob     x_sigma     i_sigma     patterns_offse n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +--------+ +---------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 26dc2ce7668fb9 42       4         0.4        0.1         5.0         0.0            500        500         4            4
# 375790809d6424 42       4         0.5        0.1         20.0        0.0            500        500         1            1
# 4b5bfbc0885f40 42       10        0.1        0.1         5.0         0.0            500        500         4            4
# 60aeef325e38e4 42       4         0.2        0.1         20.0        0.0            500        500         4            4
# 60eac5de7cd06b 42       10        0.1        0.1         10.0        0.0            500        500         4            4
# ...

# %%
ExcConfig10Plus()
# Out:
# *config_id     seed     g_dim     g_prob     x_sigma     i_sigma     patterns_offse n_tune     n_draws     n_chains     n_cores
# +------------+ +------+ +-------+ +--------+ +---------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+
# 1471bb4c9d5e84 42       10        0.2        1.0         20.0        0.0            500        500         4            4
# 15a3e0292d3a15 42       20        0.1        0.1         10.0        0.0            500        500         4            4
# 15c6c167b889fa 42       20        0.2        1.0         10.0        0.0            500        500         4            4
# 1ec89c87ac5460 42       20        0.2        0.01        5.0         0.0            500        500         4            4
# 21c0c97a86495d 42       10        0.2        0.01        5.0         0.0            500        500         4            4
# ...

# %%
ExcResult10Plus()
# Out:
# *config_id    all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +-----------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
#
#  (Total: 0)

# %%
schema.jobs
# Out:
# *table_name    *key_hash      status       key        error_message  error_stac user           host      pid       connection_id  timestamp
# +------------+ +------------+ +----------+ +--------+ +------------+ +--------+ +------------+ +-------+ +-------+ +------------+ +------------+
# __exc_result10 007f7f73b0db67 reserved     =BLOB=                    =BLOB=     sshrinivasan@k g3081     12880     70946          2023-11-30 13:
# __exc_result10 04a4c44ad95db2 reserved     =BLOB=                    =BLOB=     sshrinivasan@k g3045     79010     70954          2023-11-30 13:
# __exc_result10 1b0c96fe3d92e2 reserved     =BLOB=                    =BLOB=     sshrinivasan@k g3014     81018     70899          2023-11-30 11:
# __exc_result10 1faaab787d8a43 reserved     =BLOB=                    =BLOB=     sshrinivasan@k n3023     67909     70945          2023-11-30 13:
# ...
