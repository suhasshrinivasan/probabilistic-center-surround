# %%
from experiments.dj_experiments.exc_tables import ExcConfig, ExcResult, schema
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# [2023-11-29 11:49:32,979][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2023-11-29 11:49:33,076][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
result = ExcConfig() * ExcResult()

# %%
from experiments.dj_experiments.exc_tables import schema

# %%
result
# Out:
# *config_id     seed     g_dim     g_prob     x_sigma     i_sigma     patterns_offse n_tune     n_draws     n_chains     n_cores     all_idata  all_stimul all_g_mean all_g_mean all_center all_center all_center all_center
# +------------+ +------+ +-------+ +--------+ +---------+ +---------+ +------------+ +--------+ +---------+ +----------+ +---------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 26dc2ce7668fb9 42       4         0.4        0.1         5.0         0.0            500        500         4            4           =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 375790809d6424 42       4         0.5        0.1         20.0        0.0            500        500         1            1           =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# ...

# %%
result_dict = (result & "config_id = '6be2bcfa4678223960bd740eb55dc90b'").fetch1(download_path='/tmp/')

# %%
result_dict.keys()
# Out:
# dict_keys(['config_id', 'seed', 'g_dim', 'g_prob', 'x_sigma', 'i_sigma', 'patterns_offset', 'n_tune', 'n_draws', 'n_chains', 'n_cores', 'all_idata', 'all_stimuli', 'all_g_means', 'all_g_means_sde', 'all_center_x_means', 'all_center_x_means_sde', 'all_center_x_perc_change_means', 'all_center_x_perc_change_means_sde'])

# %%
result_dict['all_center_x_perc_change_means']
# Out:
# [[-0.2961752447910132,
#   -0.04028727888012944,
#   -0.18569886908022737,
#   0.0002768884991614755],
#  [0.23895333696071164,
#   0.07927010179965796,
#   0.07866054423182532,
#   0.12664032297381578],
#  [0.0024858399233616893,
#   0.13530082162841203,
#   0.4063004882015348,
#   0.05519268445148054],
#  [0.2261662730990704,
#   0.18223145651734335,
#   0.21102133675138238,
#   0.3736837710027082]]

# %%
result_dict['all_g_means']
# Out:
# [[array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])],
#  [array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])],
#  [array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])],
#  [array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])]]

# %%
result_dict['all_g_means_sde']
# Out:
# [[array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])],
#  [array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])],
#  [array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])],
#  [array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.]),
#   array([0., 0., 0., 0.])]]
